# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
print("The mean of Sepal length: ", df["SepalLengthCm"].mean())
print("The mean of Sepal width: ", df["SepalWidthCm"].mean())

print("The mean of Petal length: ", df["PetalLengthCm"].mean())
print("The mean of Petal width: ", df["PetalWidthCm"].mean())
# Out:
# The mean of Sepal length:  5.843333333333334
# The mean of Sepal width:  3.0540000000000003
# The mean of Petal length:  3.758666666666666
# The mean of Petal width:  1.1986666666666668

# %%
print("The median of Sepal length: ", df["SepalLengthCm"].median())
print("The median of Sepal width: ", df["SepalWidthCm"].median())

print("The median of Petal length: ", df["PetalLengthCm"].median())
print("The median of Petal width: ", df["PetalWidthCm"].median())
# Out:
# The median of Sepal length:  5.8
# The median of Sepal width:  3.0
# The median of Petal length:  4.35
# The median of Petal width:  1.3

# %%
print("The minimum of Sepal length: ", df["SepalLengthCm"].min())
print("The minimum of Sepal width: ", df["SepalWidthCm"].min())

print("The minimum of Petal length: ", df["PetalLengthCm"].min())
print("The minimum of Petal width: ", df["PetalWidthCm"].min())
# Out:
# The minimum of Sepal length:  4.3
# The minimum of Sepal width:  2.0
# The minimum of Petal length:  1.0
# The minimum of Petal width:  0.1

# %%
print("The maximum of Sepal length: ", df["SepalLengthCm"].max())
print("The median of Sepal width: ", df["SepalWidthCm"].max())

print("The maximum of Petal length: ", df["PetalLengthCm"].max())
print("The maximum of Petal width: ", df["PetalWidthCm"].max())
# Out:
# The maximum of Sepal length:  7.9
# The median of Sepal width:  4.4
# The maximum of Petal length:  6.9
# The maximum of Petal width:  2.5

# %%
print("The standard deviation of Sepal length: ", df["SepalLengthCm"].std())
print("The standard deviation of Sepal width: ", df["SepalWidthCm"].std())

print("The standard deviation of Petal length: ", df["PetalLengthCm"].std())
print("The standard deviation of Petal width: ", df["PetalWidthCm"].std())
# Out:
# The standard deviation of Sepal length:  0.828066127977863
# The standard deviation of Sepal width:  0.4335943113621737
# The standard deviation of Petal length:  1.7644204199522626
# The standard deviation of Petal width:  0.7631607417008411

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["Species"].nunique()
print(df["Species"].value_counts())
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df[100:150]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
print("The mean of Iris-setosa Species: ", end = " ")
df[df["Species"] == "Iris-setosa"].mean()
# Out:
# The mean of Iris-setosa Species:
# <ipython-input-16-dffb932e7393>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["Species"] == "Iris-setosa"].mean()
# Id               25.500
# SepalLengthCm     5.006
# SepalWidthCm      3.418
# PetalLengthCm     1.464
# PetalWidthCm      0.244
# dtype: float64

# %%
print("The mean of Iris-versicolor Species: ", end = " ")
df[df["Species"] == "Iris-versicolor"].mean()
# Out:
# The mean of Iris-versicolor Species:
# <ipython-input-17-8e9576967f16>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["Species"] == "Iris-versicolor"].mean()
# Id               75.500
# SepalLengthCm     5.936
# SepalWidthCm      2.770
# PetalLengthCm     4.260
# PetalWidthCm      1.326
# dtype: float64

# %%
print("The mean of Iris-virginica Species: ", end = " ")
df[df["Species"] == "Iris-virginica"].mean()
# Out:
# The mean of Iris-virginica Species:
# <ipython-input-18-7f6ada0cc54f>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["Species"] == "Iris-virginica"].mean()
# Id               125.500
# SepalLengthCm      6.588
# SepalWidthCm       2.974
# PetalLengthCm      5.552
# PetalWidthCm       2.026
# dtype: float64

# %%
print("The std of Iris-setosa Species: ", end = " ")
df[df["Species"] == "Iris-setosa"].std()
# Out:
# The std of Iris-setosa Species:
# <ipython-input-19-a45f44ee4604>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["Species"] == "Iris-setosa"].std()
# Id               14.577380
# SepalLengthCm     0.352490
# SepalWidthCm      0.381024
# PetalLengthCm     0.173511
# PetalWidthCm      0.107210
# dtype: float64

# %%
print("The std of Iris-versicolor Species: ", end = " ")
df[df["Species"] == "Iris-versicolor"].std()
# Out:
# The std of Iris-versicolor Species:
# <ipython-input-20-4069192d5fd0>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["Species"] == "Iris-versicolor"].std()
# Id               14.577380
# SepalLengthCm     0.516171
# SepalWidthCm      0.313798
# PetalLengthCm     0.469911
# PetalWidthCm      0.197753
# dtype: float64

# %%
print("The std of Iris-virginica Species: ", end = " ")
df[df["Species"] == "Iris-virginica"].std()
# Out:
# The std of Iris-virginica Species:
# <ipython-input-21-fd3dcf11cb58>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["Species"] == "Iris-virginica"].std()
# Id               14.577380
# SepalLengthCm     0.635880
# SepalWidthCm      0.322497
# PetalLengthCm     0.551895
# PetalWidthCm      0.274650
# dtype: float64

# %%
df1 = df[df["Species"] == "Iris-setosa"]
df1.describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
df2 = df[df["Species"] == "Iris-versicolor"]
df2.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
df3 = df[df["Species"] == "Iris-virginica"]
df3.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000

# %%
df.groupby("Species")["SepalLengthCm"].describe()
# Out:
#                  count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa       50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor   50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica    50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
df.groupby("Species")["SepalWidthCm"].describe()
# Out:
#                  count   mean       std  min    25%  50%    75%  max
# Species
# Iris-setosa       50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# Iris-versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Iris-virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
df.groupby("Species")["PetalLengthCm"].describe()
# Out:
#                  count   mean       std  min  25%   50%    75%  max
# Species
# Iris-setosa       50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
df.groupby("Species")["PetalWidthCm"].describe()
# Out:
#                  count   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa       50.0  0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor   50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica    50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5

# %%
df[df.isnull().any(axis = 'columns')]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df["Species"].drop_duplicates()
# Out:
# 0          Iris-setosa
# 50     Iris-versicolor
# 100     Iris-virginica
# Name: Species, dtype: object

# %%
df["Species"] = df["Species"].astype("category")
df.dtypes
# Out:
# Id                  int64
# SepalLengthCm     float64
# SepalWidthCm      float64
# PetalLengthCm     float64
# PetalWidthCm      float64
# Species          category
# dtype: object

# %%
data1 = df.groupby("Species")["SepalLengthCm"].describe()
data1
# Out:
#                  count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa       50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor   50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica    50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
data2 = df.groupby("Species")["SepalWidthCm"].describe()
data2
# Out:
#                  count   mean       std  min    25%  50%    75%  max
# Species
# Iris-setosa       50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# Iris-versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Iris-virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
data3 = df.groupby("Species")["PetalLengthCm"].describe()
data3
# Out:
#                  count   mean       std  min  25%   50%    75%  max
# Species
# Iris-setosa       50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
data4 = df.groupby("Species")["PetalWidthCm"].describe()
data4
# Out:
#                  count   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa       50.0  0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor   50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica    50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5

# %%
plt.figure(figsize=(4, 3))
plt.bar(["Iris-setosa", "Iris-versicolor", "Iris-virginica"], data1["mean"])
plt.title("SepalLengthCm-Mean")

plt.figure(figsize=(4, 3))
plt.bar(["Iris-setosa", "Iris-versicolor", "Iris-virginica"], data2["mean"])
plt.title("SepalWidthCm-Mean")

plt.figure(figsize=(4, 3))
plt.bar(["Iris-setosa", "Iris-versicolor", "Iris-virginica"], data3["mean"])
plt.title("PetalLengthCm-Mean")

plt.figure(figsize=(4, 3))
plt.bar(["Iris-setosa", "Iris-versicolor", "Iris-virginica"], data4["mean"])
plt.title("PetalWidthCm-Mean")
# Out:
# Text(0.5, 1.0, 'PetalWidthCm-Mean')
