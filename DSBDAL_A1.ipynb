# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/content/StudentsPerformance_modified.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course math score  reading score  writing score
# 0                    none         72           72.0           74.0
# 1               completed         69           90.0           88.0
# 2                    none         90           95.0           93.0
# 3                    none         47           57.0           44.0
# 4                    none         76           78.0           75.0

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   992 non-null    object
#  6   reading score                994 non-null    float64
#  7   writing score                991 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        reading score  writing score
# count     994.000000     991.000000
# mean       68.008048      69.487386
# std        16.602270      29.563757
# min         3.000000      10.000000
# 25%        58.000000      57.000000
# 50%        69.500000      69.000000
# 75%        79.000000      79.000000
# max       100.000000     567.000000

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     8
# reading score                  6
# writing score                  9
# dtype: int64

# %%
df['math score'].unique()
# Out:
# array(['72', '69', '90', '47', '76', '71', '88', '40', '64', '38', '58',
#        '65', '78', '50', nan, '74', '73', '67', '70', '62', '63', '56',
#        '81', '75', '57', '55', '53', '59', '66', '82', '77', '33', '52',
#        '0', '79', '39', '45', '60', '61', '41', '49', '44', '30', '80',
#        '42', '27', '43', '68', '85', '98', '87', '54', '51', '99', '84',
#        '91', '83', '89', '22', '100', '96', '94', '46', '97', '48', '35',
#        '34', '86', '92', '37', '28', '24', '113', '123', '?', '-89', '26',
#        '334', '95', '36', '29', '32', '93', '19', '23', '8'], dtype=object)

# %%
df1 = df.copy()
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
df1["math score"] = df1["math score"].astype("str")
print(df1.dtypes)
len(df1["math score"].unique())
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object
# 86

# %%
mask = df1["math score"] == "?"

# print(mask)
df1 = df1[~mask]

# df1["math score"].unique()

# %%
mask[435]
# Out:
# True

# %%
df1.replace('nan', np.nan, inplace=True)
# Out:
# <ipython-input-15-3b5b7ea37a01>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('nan', np.nan, inplace=True)

# %%
df1 = df1.dropna()
df1 = df1.reset_index(drop=True)
df1.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
# df1["math score"] = pd.to_numeric(df1["math score"])
df1["math score"] = df1["math score"].astype("int64")
df1.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                       int64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df1.describe()
# Out:
#        math score  reading score  writing score
# count  943.000000     943.000000     943.000000
# mean    66.274655      68.489926      69.650053
# std     18.369580      15.994348      30.115181
# min    -89.000000       3.000000      10.000000
# 25%     57.000000      59.000000      58.000000
# 50%     66.000000      70.000000      69.000000
# 75%     77.000000      79.000000      79.000000
# max    334.000000     100.000000     567.000000

# %%
df1.isna().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                     False
# reading score                  False
# writing score                  False
# dtype: bool

# %%
df1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0

# %%
label_encoder = LabelEncoder()
df1['Gender_encoded'] = label_encoder.fit_transform(df1['gender'])

# %%
df1.drop(['gender'], axis='columns', inplace=True)
df1.head()
# Out:
#   race/ethnicity parental level of education         lunch  \
# 0        group B           bachelor's degree      standard
# 1        group C                some college      standard
# 2        group B             master's degree      standard
# 3        group A          associate's degree  free/reduced
# 4        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0
#
#    Gender_encoded
# 0               0
# 1               0
# 2               0
# 3               1
# 4               1

# %%
df1['lunch'].value_counts()
# Out:
# standard        613
# free/reduced    330
# Name: lunch, dtype: int64

# %%
one_hot_encoded_data = pd.get_dummies(df1, columns = ['lunch'])

# %%
one_hot_encoded_data
# Out:
#     race/ethnicity parental level of education test preparation course  \
# 0          group B           bachelor's degree                    none
# 1          group C                some college               completed
# 2          group B             master's degree                    none
# 3          group A          associate's degree                    none
# 4          group C                some college                    none
# ..             ...                         ...                     ...
# 938        group E             master's degree               completed
# 939        group C                 high school                    none
# 940        group C                 high school               completed
# 941        group D                some college               completed
# 942        group D                some college                    none
#
#      math score  reading score  writing score  Gender_encoded  \
# ...

# %%
df1.head()
# Out:
#   race/ethnicity parental level of education         lunch  \
# 0        group B           bachelor's degree      standard
# 1        group C                some college      standard
# 2        group B             master's degree      standard
# 3        group A          associate's degree  free/reduced
# 4        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0
#
#    Gender_encoded
# 0               0
# 1               0
# 2               0
# 3               1
# 4               1

# %%
df1 = pd.concat([df1, one_hot_encoded_data['lunch_free/reduced']], axis = 'columns')
df1 = pd.concat([df1, one_hot_encoded_data['lunch_standard']], axis='columns')

df1.head()
# Out:
#   race/ethnicity parental level of education         lunch  \
# 0        group B           bachelor's degree      standard
# 1        group C                some college      standard
# 2        group B             master's degree      standard
# 3        group A          associate's degree  free/reduced
# 4        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0
#
#    Gender_encoded  lunch_free/reduced  lunch_standard
# 0               0                   0               1
# 1               0                   0               1
# ...

# %%
df1.drop(['lunch'], axis = 'columns', inplace=True)

# %%
df1
# Out:
#     race/ethnicity parental level of education test preparation course  \
# 0          group B           bachelor's degree                    none
# 1          group C                some college               completed
# 2          group B             master's degree                    none
# 3          group A          associate's degree                    none
# 4          group C                some college                    none
# ..             ...                         ...                     ...
# 938        group E             master's degree               completed
# 939        group C                 high school                    none
# 940        group C                 high school               completed
# 941        group D                some college               completed
# 942        group D                some college                    none
#
#      math score  reading score  writing score  Gender_encoded  \
# ...

# %%
df1["race/ethnicity"].value_counts()
# Out:
# group C    297
# group D    247
# group B    180
# group E    134
# group A     85
# Name: race/ethnicity, dtype: int64
