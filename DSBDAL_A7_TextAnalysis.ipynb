# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.2)

# %% [markdown]
# Tokenization
#
#
# Tokenization is the process of breaking down the given text in natural language processing into the smallest unit in a sentence called a token.

# %%
import textblob
from textblob import TextBlob

# %%
text = "Hello everyone! Welcome to my blog post on Medium. We are studying Natural Language Processing."

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
TextBlob(text).words
# Out:
# WordList(['Hello', 'everyone', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing'])

# %%
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

# %%
tokens_sents = nltk.sent_tokenize(text)
print(tokens_sents)
# Out:
# ['Hello everyone!', 'Welcome to my blog post on Medium.', 'We are studying Natural Language Processing.']

# %%
tokens_words = nltk.word_tokenize(text)
print(tokens_words)
# Out:
# ['Hello', 'everyone', '!', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', '.', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing', '.']

# %% [markdown]
# Stemming
#
#
# Stemming is definitely the simpler of the two approaches. With stemming, words are reduced to their word stems. A word stem need not be the same root as a dictionary-based morphological root, it just is an equal to or smaller form of the word.

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()
word = ("civilization")
ps.stem(word)
# Out:
# 'civil'

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer(language = "english")
word = "civilization"
stemmer.stem(word)
# Out:
# 'civil'

# %% [markdown]
# Lemmatization
#
#
# Lemmatization is the process of finding the form of the related word in the dictionary. It is different from Stemming. It involves longer processes to calculate than Stemming.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Lemmatize single word

print(lemmatizer.lemmatize("workers"))
print(lemmatizer.lemmatize("beeches"))
# Out:
# worker
# beech

# %%
text = "Let’s lemmatize a simple sentence. We first tokenize the sentence into words using nltk.word_tokenize and then we will call lemmatizer.lemmatize() on each word. "
word_list = nltk.word_tokenize(text)
print(word_list)
# Out:
# ['Let', '’', 's', 'lemmatize', 'a', 'simple', 'sentence', '.', 'We', 'first', 'tokenize', 'the', 'sentence', 'into', 'words', 'using', 'nltk.word_tokenize', 'and', 'then', 'we', 'will', 'call', 'lemmatizer.lemmatize', '(', ')', 'on', 'each', 'word', '.']

# %%
lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
print(lemmatized_output)
# Out:
# Let ’ s lemmatize a simple sentence . We first tokenize the sentence into word using nltk.word_tokenize and then we will call lemmatizer.lemmatize ( ) on each word .

# %%
# pip install textblob

from textblob import TextBlob, Word

# %%
word = 'stripes'
w = Word(word)
w.lemmatize()
# Out:
# 'stripe'

# %%
text = "The striped bats are hanging on their feet for best"
sent = TextBlob(text)
" ". join([w.lemmatize() for w in sent.words])
# Out:
# 'The striped bat are hanging on their foot for best'

# %% [markdown]
# Part Of Speech Tagging (POS Tagging)
#
#
# 1 - Part of Speech Tagging (POS-Tag) is the labeling of the words in a text according to their word types (noun, adjective, adverb, verb, etc.)
#
#
# 2 - It is a process of converting a sentence to forms — list of words, list of tuples (where each tuple is having a form (word, tag)). The tag in case of is a part-of-speech tag, and signifies whether the word is a noun, adjective, verb, and so on.

# %%
import nltk
from nltk import word_tokenize

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
"""Parts of Speech (nltk.pos_tag list)
CC: It is the conjunction of coordinating
CD: It is a digit of cardinal
DT: It is the determiner
EX: Existential
FW: It is a foreign word
IN: Preposition and conjunction
JJ: Adjective
JJR and JJS: Adjective and superlative
LS: List marker
MD: Modal
NN: Singular noun
NNS, NNP, NNPS: Proper and plural noun
PDT: Predeterminer
WRB: Adverb of wh
WP$: Possessive wh
WP: Pronoun of wh
WDT: Determiner of wp
VBZ: Verb
VBP, VBN, VBG, VBD, VB: Forms of verbs
UH: Interjection
TO: To go
RP: Particle
RBS, RB, RBR: Adverb
PRP, PRP$: Pronoun personal and professional
"""


text = "The striped bats are hanging on their feet for best"
tokens = nltk.word_tokenize(text)
print("Parts of Speech: ",nltk.pos_tag(tokens))
# Out:
# Parts of Speech:  [('The', 'DT'), ('striped', 'JJ'), ('bats', 'NNS'), ('are', 'VBP'), ('hanging', 'VBG'), ('on', 'IN'), ('their', 'PRP$'), ('feet', 'NNS'), ('for', 'IN'), ('best', 'JJS')]

# %% [markdown]
# Stop words -
#
# The words which are generally filtered out before processing a natural language are called stop words. These are actually the most common words in any language (like articles, prepositions, pronouns, conjunctions, etc) and does not add much information to the text. Examples of a few stop words in English are “the”, “a”, “an”, “so”, “what”.

# %% [markdown]
# Libraries to remove stop words -
#
# 1 - Natural Language Toolkit (NLTK):
#
# NLTK is an amazing library to play with natural language.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords
sw_nltk = stopwords.words('english')
print(sw_nltk)

print()
print(len(sw_nltk))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
#
# 179

# %%
text = "When I first met her she was very quiet. She remained quiet during the entire two hour long journey from Stony Brook to New York."
words = [word for word in text.split() if word.lower() not in sw_nltk]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# first met quiet. remained quiet entire two hour long journey Stony Brook New York.
# Old length:  129
# New length:  82

# %% [markdown]
# 2 - spaCy:
#
# spaCy is an open-source software library for advanced NLP. This library is quite popular now and NLP practitioners use this to get their work done in the best way.

# %%
import spacy
#loading the english language small model of spacy
en = spacy.load('en_core_web_sm')
sw_spacy = en.Defaults.stop_words
print(sw_spacy)

print()
print(len(sw_spacy))
# Out:
# {'go', 'hence', 'using', 'last', 'call', 'however', 'thereafter', 'herein', 'above', 're', 'myself', 'became', 'twenty', 'keep', 'some', 'somewhere', 'than', 'himself', 'namely', 'regarding', 'whatever', 'becoming', '’s', 'more', 'nothing', 'others', 'see', 'still', 'rather', 'throughout', 'yours', 'against', 'would', 'beyond', 'hereby', 'bottom', 'done', 'after', 'but', 'every', 'twelve', 'an', 'thru', 'everyone', 'yourselves', 'please', 'elsewhere', 'must', "'ve", "'re", 'ours', 'beside', 'part', 'forty', 'they', 'made', 'top', 'ever', 'might', 'noone', 'back', 'former', 'themselves', 'nowhere', 'latterly', 'fifty', 'latter', 'hereupon', 'these', 'least', 'among', 'none', 'onto', 'always', 'yet', 'when', 'can', 'it', 'already', 'further', 'via', 'most', 'besides', 'we', '’ll', 'down', 'sometime', 'itself', 'somehow', 'do', 'between', 'not', 'will', 'move', 'something', 'were', 'never', 'sixty', 'although', 'may', 'had', 'front', 'on', 'enough', 'was', 'this', 'any', 'be', 'used', 'here', 'whereupon', 'behind', 'well', 'few', 'thereby', 'anyhow', 'under', 'afterwards', 'his', 'cannot', 'same', '‘re', 'about', 'ten', 'except', 'third', '’d', 'ourselves', 'whither', 'n‘t', 'thence', 'whereby', 'has', 'beforehand', 'in', 'three', 'nevertheless', 'off', 'someone', 'a', 'since', 'wherever', 'really', 'then', 'therein', 'to', 'should', 'does', 'so', 'another', 'much', 'him', 'own', 'whole', 'even', 'nine', 'whether', 'you', 'out', 'amongst', 'that', 'neither', 'get', 'everything', 'being', 'also', 'up', 'whom', 'give', 'again', 'therefore', '‘d', 'while', 'towards', "'ll", 'ca', 'as', 'seems', 'unless', 'amount', 'us', 'become', 'who', 'the', "'m", 'how', 'meanwhile', 'across', 'and', 'our', 'upon', 'side', 'by', 'take', 'hereafter', 'are', '‘m', 'put', 'less', 'until', 'whenever', "'d", 'around', 'before', 'them', 'name', 'there', 'next', 'no', 'seeming', 'along', 'now', 'whose', 'during', 'thus', 'serious', 'at', 'too', 'nor', 'moreover', 'though', 'within', 'two', 'perhaps', 'fifteen', 'yourself', 'what', '’ve', 'below', 'anything', 'my', 'hundred', 'very', 'whence', 'several', 'many', '‘ll', 'into', 'their', 'if', 'i', 'me', "'s", 'with', 'of', 'from', 'toward', 'whereas', 'over', 'where', 'been', 'full', 'one', 'formerly', 'anyone', 'her', 'she', 'once', 'did', 'for', 'everywhere', 'could', 'show', 'six', 'due', 'alone', 'empty', 'four', 'have', 'say', 'seemed', 'mine', 'quite', 'else', 'five', 'seem', 'why', 'often', 'those', 'indeed', 'whoever', 'becomes', 'each', 'just', 'eight', 'per', 'thereupon', 'hers', '‘ve', 'am', "n't", 'which', 'through', 'either', 'only', 'without', 'wherein', 'your', 'make', 'he', 'almost', 'herself', 'its', 'whereafter', 'or', 'first', 'otherwise', 'doing', 'is', 'because', 'nobody', '‘s', 'other', 'anywhere', 'mostly', 'such', 'eleven', 'all', 'anyway', '’m', 'sometimes', 'both', 'together', '’re', 'various', 'n’t'}
#
# 326

# %%
words = [word for word in text.split() if word.lower() not in sw_spacy]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# met quiet. remained quiet entire hour long journey Stony Brook New York.
# Old length:  129
# New length:  72

# %% [markdown]
# 3 - Gensim:
#
# Gensim (Generate Similar) is an open-source software library that uses modern statistical machine learning. According to Wikipedia, Gensim is designed to handle large text collections using data streaming and incremental online algorithms, which differentiates it from most other machine learning software packages that target only in-memory processing.

# %%
import gensim
from gensim.parsing.preprocessing import remove_stopwords, STOPWORDS
print(STOPWORDS)

print()
print(len(STOPWORDS))
# Out:
# frozenset({'go', 'hence', 'using', 'last', 'call', 'fill', 'however', 'thereafter', 'above', 're', 'myself', 'became', 'twenty', 'keep', 'some', 'somewhere', 'than', 'himself', 'namely', 'regarding', 'whatever', 'becoming', 'more', 'others', 'nothing', 'still', 'see', 'rather', 'throughout', 'yours', 'against', 'would', 'beyond', 'hereby', 'bottom', 'done', 'after', 'but', 'every', 'twelve', 'an', 'thru', 'everyone', 'yourselves', 'please', 'elsewhere', 'must', 'ours', 'beside', 'part', 'forty', 'they', 'made', 'top', 'ever', 'might', 'noone', 'back', 'found', 'former', 'themselves', 'nowhere', 'latterly', 'together', 'don', 'fifty', 'latter', 'hereupon', 'these', 'least', 'none', 'among', 'onto', 'always', 'yet', 'when', 'can', 'it', 'further', 'already', 'detail', 'via', 'most', 'besides', 'computer', 'cant', 'we', 'inc', 'couldnt', 'cry', 'down', 'sometime', 'somehow', 'itself', 'do', 'between', 'not', 'will', 'move', 'something', 'were', 'never', 'sixty', 'although', 'may', 'had', 'front', 'on', 'enough', 'was', 'this', 'doesn', 'any', 'be', 'used', 'here', 'whereupon', 'behind', 'well', 'few', 'thereby', 'anyhow', 'under', 'afterwards', 'his', 'cannot', 'same', 'ie', 'about', 'ten', 'except', 'third', 'ourselves', 'whither', 'thence', 'whereby', 'has', 'beforehand', 'in', 'find', 'three', 'someone', 'nevertheless', 'off', 'amoungst', 'a', 'since', 'wherever', 'really', 'then', 'therein', 'to', 'should', 'does', 'so', 'another', 'much', 'mill', 'him', 'own', 'whole', 'even', 'hasnt', 'nine', 'system', 'whether', 'you', 'out', 'amongst', 'that', 'etc', 'neither', 'km', 'get', 'everything', 'being', 'fire', 'also', 'up', 'whom', 'give', 'again', 'therefore', 'while', 'towards', 'seems', 'as', 'interest', 'unless', 'amount', 'bill', 'us', 'become', 'who', 'the', 'how', 'meanwhile', 'across', 'and', 'our', 'upon', 'side', 'by', 'take', 'hereafter', 'are', 'put', 'less', 'until', 'whenever', 'around', 'before', 'them', 'name', 'there', 'seeming', 'next', 'no', 'along', 'de', 'now', 'whose', 'during', 'thus', 'serious', 'at', 'too', 'nor', 'moreover', 'within', 'though', 'ltd', 'two', 'perhaps', 'fifteen', 'yourself', 'what', 'co', 'un', 'below', 'anything', 'my', 'hundred', 'very', 'whence', 'several', 'many', 'into', 'their', 'if', 'i', 'me', 'with', 'of', 'from', 'toward', 'whereas', 'over', 'where', 'been', 'full', 'one', 'formerly', 'anyone', 'didn', 'her', 'she', 'once', 'did', 'for', 'everywhere', 'could', 'show', 'six', 'due', 'alone', 'four', 'empty', 'have', 'say', 'seemed', 'mine', 'quite', 'else', 'seem', 'why', 'five', 'con', 'often', 'those', 'indeed', 'describe', 'whoever', 'becomes', 'each', 'just', 'per', 'eight', 'thereupon', 'hers', 'am', 'eg', 'which', 'through', 'either', 'only', 'without', 'wherein', 'your', 'make', 'he', 'almost', 'herself', 'thick', 'its', 'whereafter', 'or', 'first', 'otherwise', 'doing', 'is', 'because', 'nobody', 'other', 'sincere', 'anywhere', 'mostly', 'such', 'eleven', 'all', 'kg', 'anyway', 'sometimes', 'thin', 'both', 'herein', 'various'})
#
# 337

# %%
new_text = remove_stopwords(text)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# When I met quiet. She remained quiet entire hour long journey Stony Brook New York.
# Old length:  129
# New length:  83

# %% [markdown]
# 4 - Scikit-Learn:
#
# Scikit-Learn needs no introduction. It is a free software machine learning library for Python. It is probably the most powerful library for machine learning.

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
print(ENGLISH_STOP_WORDS)

print()
print(len(ENGLISH_STOP_WORDS))
# Out:
# frozenset({'go', 'hence', 'last', 'call', 'fill', 'however', 'thereafter', 'herein', 'above', 're', 'myself', 'became', 'twenty', 'keep', 'some', 'somewhere', 'than', 'himself', 'namely', 'whatever', 'becoming', 'more', 'nothing', 'others', 'see', 'still', 'rather', 'throughout', 'yours', 'against', 'would', 'beyond', 'hereby', 'bottom', 'done', 'after', 'but', 'every', 'twelve', 'an', 'thru', 'everyone', 'yourselves', 'please', 'elsewhere', 'must', 'ours', 'beside', 'part', 'forty', 'they', 'made', 'top', 'ever', 'might', 'noone', 'back', 'found', 'former', 'themselves', 'nowhere', 'latterly', 'fifty', 'latter', 'hereupon', 'these', 'least', 'among', 'none', 'onto', 'always', 'yet', 'when', 'can', 'it', 'already', 'further', 'detail', 'via', 'most', 'besides', 'cant', 'we', 'inc', 'couldnt', 'cry', 'down', 'sometime', 'itself', 'somehow', 'do', 'between', 'not', 'will', 'move', 'something', 'were', 'never', 'sixty', 'although', 'may', 'had', 'front', 'on', 'enough', 'was', 'this', 'any', 'be', 'here', 'whereupon', 'behind', 'well', 'few', 'thereby', 'anyhow', 'under', 'afterwards', 'his', 'cannot', 'same', 'ie', 'about', 'ten', 'except', 'third', 'ourselves', 'whither', 'thence', 'whereby', 'has', 'beforehand', 'in', 'find', 'three', 'nevertheless', 'off', 'someone', 'amoungst', 'a', 'since', 'wherever', 'then', 'therein', 'to', 'should', 'so', 'another', 'much', 'mill', 'him', 'own', 'whole', 'even', 'hasnt', 'nine', 'system', 'whether', 'you', 'out', 'amongst', 'that', 'etc', 'neither', 'get', 'everything', 'being', 'fire', 'also', 'up', 'whom', 'give', 'again', 'therefore', 'while', 'towards', 'seems', 'as', 'interest', 'amount', 'bill', 'us', 'become', 'who', 'the', 'how', 'meanwhile', 'across', 'and', 'our', 'upon', 'side', 'by', 'take', 'hereafter', 'are', 'put', 'less', 'until', 'whenever', 'around', 'before', 'them', 'name', 'there', 'next', 'no', 'seeming', 'along', 'de', 'now', 'whose', 'during', 'thus', 'serious', 'at', 'too', 'nor', 'moreover', 'though', 'within', 'ltd', 'two', 'perhaps', 'fifteen', 'yourself', 'what', 'co', 'un', 'below', 'anything', 'my', 'hundred', 'very', 'whence', 'several', 'many', 'into', 'their', 'if', 'i', 'me', 'with', 'of', 'from', 'toward', 'whereas', 'over', 'where', 'been', 'full', 'one', 'formerly', 'anyone', 'her', 'she', 'once', 'for', 'everywhere', 'could', 'show', 'six', 'due', 'alone', 'empty', 'four', 'have', 'seemed', 'mine', 'else', 'five', 'seem', 'why', 'con', 'often', 'those', 'indeed', 'describe', 'whoever', 'becomes', 'each', 'eight', 'per', 'thereupon', 'hers', 'am', 'eg', 'which', 'through', 'either', 'only', 'without', 'wherein', 'your', 'he', 'almost', 'herself', 'thick', 'its', 'whereafter', 'or', 'first', 'otherwise', 'is', 'because', 'nobody', 'other', 'sincere', 'anywhere', 'mostly', 'such', 'eleven', 'all', 'anyway', 'sometimes', 'thin', 'both', 'together'})
#
# 318

# %%
words = [word for word in text.split() if word.lower() not in ENGLISH_STOP_WORDS]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# met quiet. remained quiet entire hour long journey Stony Brook New York.
# Old length:  129
# New length:  72

# %%
sw_nltk.extend(['first', 'second', 'third', 'me'])
print(len(sw_nltk))
# Out:
# 183

# %%
sw_nltk.remove('not')
print(len(sw_nltk))
# Out:
# 182

# %% [markdown]
# Custom Stop Words Removal -
#
#
# If we do not want to use any of these libraries, we can also create our own custom stop words list and use it in our task. This is usually done when we have domain expertise in our field and when we know which words we should avoid while performing our task.

# %%
my_stop_words = ['her','me','i','she','it']
words = [word for word in text.split() if word.lower() not in my_stop_words]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# When first met was very quiet. remained quiet during the entire two hour long journey from Stony Brook to New York.
# Old length:  129
# New length:  115
