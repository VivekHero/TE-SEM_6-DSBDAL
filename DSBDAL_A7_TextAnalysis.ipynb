# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.2)

# %% [markdown]
# Tokenization
#
#
# Tokenization is the process of breaking down the given text in natural language processing into the smallest unit in a sentence called a token.

# %%
import textblob
from textblob import TextBlob

# %%
text = "Hello everyone! Welcome to my blog post on Medium. We are studying Natural Language Processing."

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
TextBlob(text).words
# Out:
# WordList(['Hello', 'everyone', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing'])

# %%
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

# %%
tokens_sents = nltk.sent_tokenize(text)
print(tokens_sents)
# Out:
# ['Hello everyone!', 'Welcome to my blog post on Medium.', 'We are studying Natural Language Processing.']

# %%
tokens_words = nltk.word_tokenize(text)
print(tokens_words)
# Out:
# ['Hello', 'everyone', '!', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', '.', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing', '.']

# %% [markdown]
# Stemming
#
#
# Stemming is definitely the simpler of the two approaches. With stemming, words are reduced to their word stems. A word stem need not be the same root as a dictionary-based morphological root, it just is an equal to or smaller form of the word.

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()
word = ("civilization")
ps.stem(word)
# Out:
# 'civil'

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer(language = "english")
word = "civilization"
stemmer.stem(word)
# Out:
# 'civil'

# %% [markdown]
# Lemmatization
#
#
# Lemmatization is the process of finding the form of the related word in the dictionary. It is different from Stemming. It involves longer processes to calculate than Stemming.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Lemmatize single word

print(lemmatizer.lemmatize("workers"))
print(lemmatizer.lemmatize("beeches"))
# Out:
# worker
# beech

# %%
text = "Let’s lemmatize a simple sentence. We first tokenize the sentence into words using nltk.word_tokenize and then we will call lemmatizer.lemmatize() on each word. "
word_list = nltk.word_tokenize(text)
print(word_list)
# Out:
# ['Let', '’', 's', 'lemmatize', 'a', 'simple', 'sentence', '.', 'We', 'first', 'tokenize', 'the', 'sentence', 'into', 'words', 'using', 'nltk.word_tokenize', 'and', 'then', 'we', 'will', 'call', 'lemmatizer.lemmatize', '(', ')', 'on', 'each', 'word', '.']

# %%
lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
print(lemmatized_output)
# Out:
# Let ’ s lemmatize a simple sentence . We first tokenize the sentence into word using nltk.word_tokenize and then we will call lemmatizer.lemmatize ( ) on each word .

# %%
# pip install textblob

from textblob import TextBlob, Word

# %%
word = 'stripes'
w = Word(word)
w.lemmatize()
# Out:
# 'stripe'

# %%
text = "The striped bats are hanging on their feet for best"
sent = TextBlob(text)
" ". join([w.lemmatize() for w in sent.words])
# Out:
# 'The striped bat are hanging on their foot for best'

# %% [markdown]
# Part Of Speech Tagging (POS Tagging)
#
#
# 1 - Part of Speech Tagging (POS-Tag) is the labeling of the words in a text according to their word types (noun, adjective, adverb, verb, etc.)
#
#
# 2 - It is a process of converting a sentence to forms — list of words, list of tuples (where each tuple is having a form (word, tag)). The tag in case of is a part-of-speech tag, and signifies whether the word is a noun, adjective, verb, and so on.

# %%
import nltk
from nltk import word_tokenize

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = "The striped bats are hanging on their feet for best"
tokens = nltk.word_tokenize(text)
print("Parts of Speech: ",nltk.pos_tag(tokens))
# Out:
# Parts of Speech:  [('The', 'DT'), ('striped', 'JJ'), ('bats', 'NNS'), ('are', 'VBP'), ('hanging', 'VBG'), ('on', 'IN'), ('their', 'PRP$'), ('feet', 'NNS'), ('for', 'IN'), ('best', 'JJS')]

# %% [markdown]
# Stop words -
#
# The words which are generally filtered out before processing a natural language are called stop words. These are actually the most common words in any language (like articles, prepositions, pronouns, conjunctions, etc) and does not add much information to the text. Examples of a few stop words in English are “the”, “a”, “an”, “so”, “what”.

# %% [markdown]
# Libraries to remove stop words -
#
# 1 - Natural Language Toolkit (NLTK):
#
# NLTK is an amazing library to play with natural language.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
sw_nltk = stopwords.words('english')
print(sw_nltk)

print()
print(len(sw_nltk))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
#
# 179

# %%
text = "When I first met her she was very quiet. She remained quiet during the entire two hour long journey from Stony Brook to New York."
words = [word for word in text.split() if word.lower() not in sw_nltk]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# first met quiet. remained quiet entire two hour long journey Stony Brook New York.
# Old length:  129
# New length:  82

# %% [markdown]
# 2 - spaCy:
#
# spaCy is an open-source software library for advanced NLP. This library is quite popular now and NLP practitioners use this to get their work done in the best way.

# %%
import spacy
#loading the english language small model of spacy
en = spacy.load('en_core_web_sm')
sw_spacy = en.Defaults.stop_words
print(sw_spacy)

print()
print(len(sw_spacy))
# Out:
# {'might', 'almost', '‘ll', 'anyway', 'ourselves', 'nothing', 'us', 'when', 'many', 'not', 'ever', 'could', 'whereas', 'among', 'while', 'except', 'somewhere', 'onto', 'anyhow', 'by', 'per', 'therefore', 'an', 'bottom', 'serious', 'somehow', 'using', 'amount', 'besides', 'seems', '’m', 'those', 'perhaps', 'just', 'meanwhile', 'none', 'will', 'into', 'sixty', 'hundred', 'few', 'your', 'across', 'such', 'sometime', '‘s', 'really', 'ten', 'n‘t', 'our', 'call', 'had', 'it', 'empty', 'only', 'about', 'my', 'did', 'someone', 'nor', 'own', 'else', 'noone', 'see', 'mostly', "'ve", 'through', 'whereafter', 'then', 'i', 'along', 'namely', 'he', 'twelve', 'were', 'or', 'together', 'how', 'fifteen', 'eight', 'without', 'seeming', 'seem', '‘m', 'should', 'become', 'thence', 'yet', 'always', 'wherever', 'something', 'with', 'are', 'still', 'ours', 'please', 'as', 'ca', 're', 'herein', 'himself', 'whence', 'from', 'themselves', 'another', 'beyond', 'rather', 'nowhere', 'off', 'whole', 'even', 'thereafter', '‘d', "'ll", 'hence', 'hereupon', 'beforehand', 'has', 'elsewhere', 'various', 'may', 'for', 'both', 'via', 'been', 'this', 'during', 'wherein', 'unless', 'now', 'no', "'m", 'she', '’s', 'at', 'if', 'formerly', 'where', 'in', 'neither', 'latterly', 'herself', "'s", 'to', 'yourself', 'eleven', "'re", 'any', 'most', 'of', 'they', 'but', 'her', 'fifty', 'down', 'also', 'would', 'much', 'done', '’d', 'n’t', 'him', 'itself', 'out', 'otherwise', 'nine', 'forty', '’ve', 'under', 'must', 'moreover', 'thus', 'against', 'its', 'whose', 'back', 'than', 'enough', 'does', 'we', 'because', 'their', 'top', 'two', 'full', 'show', 'is', '‘re', 'within', 'yours', 'since', 'mine', 'put', 'can', 'anyone', 'next', 'toward', 'however', 'every', 'sometimes', '’re', 'before', 'behind', 'whereby', 'towards', "n't", 'make', 'part', 'becomes', 'do', 'after', 'made', '‘ve', 'upon', 'give', 'move', 'whom', 'the', 'what', 'became', 'so', 'often', 'amongst', 'twenty', 'seemed', 'myself', 'less', 'everything', 'everyone', 'further', 'whatever', 'used', 'anything', 'there', 'third', 'whereupon', 'well', 'front', 'yourselves', 'get', 'be', 'and', 'name', 'everywhere', 'say', 'alone', 'already', 'whenever', 'afterwards', 'too', 'indeed', 'hereafter', 'three', 'therein', 'least', 'between', 'becoming', 'one', 'anywhere', 'very', 'take', 'keep', 'all', 'them', 'whoever', 'hereby', 'nobody', 'which', 'below', 'throughout', 'was', 'nevertheless', 'each', 'four', 'thereby', 'these', 'his', 'why', 'again', 'although', 'that', 'regarding', 'being', 'first', 'once', 'me', 'side', 'who', 'over', 'five', 'same', 'hers', 'am', "'d", 'thereupon', 'have', 'here', 'last', 'whether', 'cannot', 'whither', 'others', 'some', 'you', 'several', 'up', 'go', 'more', 'latter', 'either', 'around', 'doing', 'above', 'due', 'quite', 'beside', 'until', 'six', '’ll', 'other', 'thru', 'on', 'never', 'a', 'former', 'though'}
#
# 326

# %%
words = [word for word in text.split() if word.lower() not in sw_spacy]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# met quiet. remained quiet entire hour long journey Stony Brook New York.
# Old length:  129
# New length:  72

# %% [markdown]
# 3 - Gensim:
#
# Gensim (Generate Similar) is an open-source software library that uses modern statistical machine learning. According to Wikipedia, Gensim is designed to handle large text collections using data streaming and incremental online algorithms, which differentiates it from most other machine learning software packages that target only in-memory processing.

# %%
import gensim
from gensim.parsing.preprocessing import remove_stopwords, STOPWORDS
print(STOPWORDS)

print()
print(len(STOPWORDS))
# Out:
# frozenset({'might', 'almost', 'anyway', 'ourselves', 'fire', 'nothing', 'us', 'when', 'interest', 'many', 'not', 'ever', 'cry', 'could', 'whereas', 'among', 'while', 'somewhere', 'except', 'onto', 'anyhow', 'by', 'per', 'therefore', 'bottom', 'somehow', 'an', 'serious', 'using', 'amount', 'seems', 'besides', 'describe', 'those', 'perhaps', 'just', 'meanwhile', 'none', 'will', 'into', 'sixty', 'hundred', 'few', 'your', 'un', 'across', 'such', 'computer', 'ie', 'sometime', 'really', 'ten', 'our', 'had', 'call', 'it', 'empty', 'only', 'about', 'doesn', 'my', 'thick', 'did', 'someone', 'nor', 'own', 'found', 'else', 'noone', 'see', 'mostly', 'through', 'whereafter', 'then', 'i', 'namely', 'along', 'he', 'twelve', 'were', 'or', 'together', 'how', 'fifteen', 'eight', 'without', 'seeming', 'seem', 'de', 'should', 'become', 'yet', 'thence', 'always', 'wherever', 'something', 'with', 'are', 'still', 'ours', 'please', 'as', 're', 'himself', 'herein', 'whence', 'inc', 'from', 'themselves', 'another', 'beyond', 'rather', 'nowhere', 'off', 'couldnt', 'whole', 'even', 'thereafter', 'hence', 'hereupon', 'beforehand', 'has', 'elsewhere', 'amoungst', 'various', 'may', 'for', 'both', 'via', 'been', 'kg', 'this', 'during', 'wherein', 'unless', 'now', 'don', 'no', 'she', 'at', 'fill', 'if', 'formerly', 'didn', 'where', 'in', 'neither', 'latterly', 'herself', 'to', 'yourself', 'eleven', 'any', 'of', 'most', 'they', 'co', 'but', 'her', 'fifty', 'down', 'also', 'would', 'much', 'done', 'find', 'him', 'itself', 'out', 'otherwise', 'nine', 'forty', 'bill', 'under', 'must', 'moreover', 'thus', 'against', 'its', 'whose', 'back', 'than', 'enough', 'does', 'we', 'because', 'top', 'their', 'two', 'show', 'full', 'is', 'within', 'con', 'since', 'yours', 'mine', 'km', 'put', 'can', 'next', 'anyone', 'toward', 'however', 'every', 'sometimes', 'before', 'behind', 'whereby', 'towards', 'make', 'part', 'becomes', 'do', 'made', 'after', 'upon', 'give', 'move', 'whom', 'the', 'thin', 'what', 'became', 'so', 'often', 'amongst', 'twenty', 'seemed', 'myself', 'less', 'everything', 'everyone', 'further', 'whatever', 'used', 'anything', 'there', 'third', 'hasnt', 'whereupon', 'cant', 'well', 'front', 'yourselves', 'get', 'be', 'name', 'and', 'everywhere', 'say', 'alone', 'already', 'whenever', 'afterwards', 'too', 'indeed', 'hereafter', 'three', 'therein', 'ltd', 'least', 'between', 'becoming', 'one', 'anywhere', 'very', 'take', 'keep', 'all', 'them', 'whoever', 'etc', 'hereby', 'nobody', 'which', 'below', 'throughout', 'detail', 'was', 'nevertheless', 'sincere', 'each', 'four', 'thereby', 'these', 'his', 'why', 'again', 'although', 'that', 'regarding', 'being', 'first', 'once', 'me', 'side', 'who', 'over', 'five', 'same', 'hers', 'am', 'thereupon', 'have', 'here', 'last', 'whether', 'cannot', 'whither', 'others', 'some', 'mill', 'you', 'several', 'up', 'eg', 'go', 'more', 'latter', 'either', 'around', 'doing', 'above', 'due', 'quite', 'beside', 'until', 'six', 'other', 'thru', 'system', 'on', 'never', 'a', 'former', 'though'})
#
# 337

# %%
new_text = remove_stopwords(text)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# When I met quiet. She remained quiet entire hour long journey Stony Brook New York.
# Old length:  129
# New length:  83

# %% [markdown]
# 4 - Scikit-Learn:
#
# Scikit-Learn needs no introduction. It is a free software machine learning library for Python. It is probably the most powerful library for machine learning.

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
print(ENGLISH_STOP_WORDS)

print()
print(len(ENGLISH_STOP_WORDS))
# Out:
# frozenset({'might', 'almost', 'anyway', 'fire', 'ourselves', 'nothing', 'us', 'when', 'interest', 'many', 'not', 'cry', 'ever', 'could', 'whereas', 'among', 'while', 'except', 'somewhere', 'onto', 'anyhow', 'by', 'per', 'therefore', 'an', 'bottom', 'serious', 'somehow', 'amount', 'besides', 'seems', 'describe', 'those', 'perhaps', 'meanwhile', 'none', 'will', 'into', 'sixty', 'hundred', 'few', 'your', 'un', 'across', 'such', 'ie', 'sometime', 'ten', 'our', 'call', 'had', 'it', 'empty', 'only', 'about', 'my', 'thick', 'someone', 'nor', 'own', 'else', 'found', 'noone', 'see', 'mostly', 'through', 'whereafter', 'then', 'i', 'along', 'namely', 'he', 'twelve', 'were', 'or', 'together', 'how', 'fifteen', 'eight', 'without', 'seeming', 'seem', 'de', 'should', 'become', 'thence', 'yet', 'always', 'wherever', 'something', 'with', 'are', 'still', 'ours', 'please', 'as', 're', 'herein', 'himself', 'whence', 'inc', 'from', 'themselves', 'another', 'beyond', 'rather', 'nowhere', 'off', 'couldnt', 'whole', 'even', 'thereafter', 'hence', 'hereupon', 'beforehand', 'has', 'elsewhere', 'amoungst', 'may', 'for', 'both', 'via', 'been', 'this', 'during', 'wherein', 'now', 'no', 'she', 'at', 'fill', 'if', 'formerly', 'where', 'in', 'neither', 'latterly', 'herself', 'to', 'yourself', 'eleven', 'any', 'most', 'of', 'they', 'co', 'but', 'her', 'fifty', 'down', 'also', 'would', 'much', 'done', 'find', 'him', 'itself', 'out', 'otherwise', 'nine', 'forty', 'bill', 'under', 'must', 'moreover', 'thus', 'against', 'its', 'whose', 'back', 'than', 'enough', 'we', 'because', 'their', 'top', 'two', 'full', 'show', 'is', 'within', 'con', 'since', 'yours', 'mine', 'put', 'can', 'anyone', 'next', 'toward', 'however', 'every', 'sometimes', 'before', 'behind', 'whereby', 'towards', 'part', 'becomes', 'do', 'after', 'made', 'upon', 'give', 'move', 'whom', 'the', 'thin', 'what', 'became', 'so', 'often', 'amongst', 'twenty', 'seemed', 'myself', 'less', 'everything', 'everyone', 'further', 'whatever', 'anything', 'there', 'third', 'hasnt', 'cant', 'whereupon', 'well', 'front', 'yourselves', 'get', 'be', 'and', 'name', 'everywhere', 'alone', 'already', 'whenever', 'afterwards', 'too', 'indeed', 'hereafter', 'three', 'therein', 'ltd', 'least', 'between', 'becoming', 'one', 'anywhere', 'very', 'take', 'keep', 'all', 'them', 'whoever', 'etc', 'hereby', 'nobody', 'which', 'below', 'throughout', 'detail', 'was', 'nevertheless', 'sincere', 'each', 'four', 'thereby', 'these', 'his', 'why', 'again', 'although', 'that', 'being', 'first', 'once', 'me', 'side', 'who', 'over', 'five', 'same', 'hers', 'am', 'thereupon', 'have', 'here', 'last', 'whether', 'cannot', 'whither', 'others', 'some', 'mill', 'you', 'several', 'up', 'eg', 'go', 'more', 'latter', 'either', 'around', 'above', 'due', 'beside', 'until', 'six', 'other', 'thru', 'system', 'on', 'never', 'a', 'former', 'though'})
#
# 318

# %%
words = [word for word in text.split() if word.lower() not in ENGLISH_STOP_WORDS]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# met quiet. remained quiet entire hour long journey Stony Brook New York.
# Old length:  129
# New length:  72

# %%
sw_nltk.extend(['first', 'second', 'third', 'me'])
print(len(sw_nltk))
# Out:
# 183

# %%
sw_nltk.remove('not')
print(len(sw_nltk))
# Out:
# 182

# %% [markdown]
# Custom Stop Words Removal -
#
#
# If we do not want to use any of these libraries, we can also create our own custom stop words list and use it in our task. This is usually done when we have domain expertise in our field and when we know which words we should avoid while performing our task.

# %%
my_stop_words = ['her','me','i','she','it']
words = [word for word in text.split() if word.lower() not in my_stop_words]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# When first met was very quiet. remained quiet during the entire two hour long journey from Stony Brook to New York.
# Old length:  129
# New length:  115
